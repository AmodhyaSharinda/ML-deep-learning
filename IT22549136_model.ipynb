# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv("academic_dataset.csv")
data
# Out:
#     gender NationalITy PlaceofBirth       StageID GradeID SectionID  \
# 0        M          KW       KuwaIT    lowerlevel    G-04         A
# 1        M          KW       KuwaIT    lowerlevel    G-04         A
# 2        M          KW       KuwaIT    lowerlevel    G-04         A
# 3        M          KW       KuwaIT    lowerlevel    G-04         A
# 4        M          KW       KuwaIT    lowerlevel    G-04         A
# ..     ...         ...          ...           ...     ...       ...
# 475      F      Jordan       Jordan  MiddleSchool    G-08         A
# 476      F      Jordan       Jordan  MiddleSchool    G-08         A
# 477      F      Jordan       Jordan  MiddleSchool    G-08         A
# 478      F      Jordan       Jordan  MiddleSchool    G-08         A
# 479      F      Jordan       Jordan  MiddleSchool    G-08         A
#
#          Topic Semester Relation  raisedhands  VisITedResources  \
# 0           IT        F   Father           15                16
# 1           IT        F   Father           20                20
# 2           IT        F   Father           10                 7
# 3           IT        F   Father           30                25
# 4           IT        F   Father           40                50
# ..         ...      ...      ...          ...               ...
# 475  Chemistry        S   Father            5                 4
# 476    Geology        F   Father           50                77
# 477    Geology        S   Father           55                74
# 478    History        F   Father           30                17
# 479    History        S   Father           35                14
#
#      AnnouncementsView  Discussion ParentAnsweringSurvey  \
# 0                    2          20                   Yes
# 1                    3          25                   Yes
# 2                    0          30                    No
# 3                    5          35                    No
# 4                   12          50                    No
# ..                 ...         ...                   ...
# 475                  5           8                    No
# 476                 14          28                    No
# 477                 25          29                    No
# 478                 14          57                    No
# 479                 23          62                    No
#
#     ParentschoolSatisfaction StudentAbsenceDays Class
# 0                       Good            Under-7     M
# 1                       Good            Under-7     M
# 2                        Bad            Above-7     L
# 3                        Bad            Above-7     L
# 4                        Bad            Above-7     M
# ..                       ...                ...   ...
# 475                      Bad            Above-7     L
# 476                      Bad            Under-7     M
# 477                      Bad            Under-7     M
# 478                      Bad            Above-7     L
# 479                      Bad            Above-7     L
#
# [480 rows x 17 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 480 entries, 0 to 479
# Data columns (total 17 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   gender                    480 non-null    object
#  1   NationalITy               480 non-null    object
#  2   PlaceofBirth              480 non-null    object
#  3   StageID                   480 non-null    object
#  4   GradeID                   480 non-null    object
#  5   SectionID                 480 non-null    object
#  6   Topic                     480 non-null    object
#  7   Semester                  480 non-null    object
#  8   Relation                  480 non-null    object
#  9   raisedhands               480 non-null    int64
#  10  VisITedResources          480 non-null    int64
#  11  AnnouncementsView         480 non-null    int64
#  12  Discussion                480 non-null    int64
#  13  ParentAnsweringSurvey     480 non-null    object
#  14  ParentschoolSatisfaction  480 non-null    object
#  15  StudentAbsenceDays        480 non-null    object
#  16  Class                     480 non-null    object
# dtypes: int64(4), object(13)
# memory usage: 63.9+ KB

# %%
#remove duplicates
data = data.drop_duplicates()

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 478 entries, 0 to 479
# Data columns (total 17 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   gender                    478 non-null    object
#  1   NationalITy               478 non-null    object
#  2   PlaceofBirth              478 non-null    object
#  3   StageID                   478 non-null    object
#  4   GradeID                   478 non-null    object
#  5   SectionID                 478 non-null    object
#  6   Topic                     478 non-null    object
#  7   Semester                  478 non-null    object
#  8   Relation                  478 non-null    object
#  9   raisedhands               478 non-null    int64
#  10  VisITedResources          478 non-null    int64
#  11  AnnouncementsView         478 non-null    int64
#  12  Discussion                478 non-null    int64
#  13  ParentAnsweringSurvey     478 non-null    object
#  14  ParentschoolSatisfaction  478 non-null    object
#  15  StudentAbsenceDays        478 non-null    object
#  16  Class                     478 non-null    object
# dtypes: int64(4), object(13)
# memory usage: 67.2+ KB

# %%
#ckeck for missing valuess
data.isnull().sum()
# Out:
# gender                      0
# NationalITy                 0
# PlaceofBirth                0
# StageID                     0
# GradeID                     0
# SectionID                   0
# Topic                       0
# Semester                    0
# Relation                    0
# raisedhands                 0
# VisITedResources            0
# AnnouncementsView           0
# Discussion                  0
# ParentAnsweringSurvey       0
# ParentschoolSatisfaction    0
# StudentAbsenceDays          0
# Class                       0
# dtype: int64

# %%
#encoding categorical variables
from sklearn.preprocessing import LabelEncoder

# Initialize the label encoder
label_encoder = LabelEncoder()

#label encoding 
data['gender'] = label_encoder.fit_transform(data['gender'])
data['NationalITy'] = label_encoder.fit_transform(data['NationalITy'])
data['PlaceofBirth'] = label_encoder.fit_transform(data['PlaceofBirth'])
data['StageID'] = label_encoder.fit_transform(data['StageID'])
data['GradeID'] = label_encoder.fit_transform(data['GradeID'])
data['SectionID'] = label_encoder.fit_transform(data['SectionID'])
data['Topic'] = label_encoder.fit_transform(data['Topic'])
data['Semester'] = label_encoder.fit_transform(data['Semester'])
data['Relation'] = label_encoder.fit_transform(data['Relation'])
data['ParentAnsweringSurvey'] = label_encoder.fit_transform(data['ParentAnsweringSurvey'])
data['ParentschoolSatisfaction'] = label_encoder.fit_transform(data['ParentschoolSatisfaction'])
data['StudentAbsenceDays'] = label_encoder.fit_transform(data['StudentAbsenceDays'])
data['Class'] = label_encoder.fit_transform(data['Class'])
# Out:
# C:\Users\damin\AppData\Local\Temp\ipykernel_23304\2554779994.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['gender'] = label_encoder.fit_transform(data['gender'])
# C:\Users\damin\AppData\Local\Temp\ipykernel_23304\2554779994.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['NationalITy'] = label_encoder.fit_transform(data['NationalITy'])
# C:\Users\damin\AppData\Local\Temp\ipykernel_23304\2554779994.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['PlaceofBirth'] = label_encoder.fit_transform(data['PlaceofBirth'])
# C:\Users\damin\AppData\Local\Temp\ipykernel_23304\2554779994.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['StageID'] = label_encoder.fit_transform(data['StageID'])
# C:\Users\damin\AppData\Local\Temp\ipykernel_23304\2554779994.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['GradeID'] = label_encoder.fit_transform(data['GradeID'])
# C:\Users\damin\AppData\Local\Temp\ipykernel_23304\2554779994.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['SectionID'] = label_encoder.fit_transform(data['SectionID'])
# C:\Users\damin\AppData\Local\Temp\ipykernel_23304\2554779994.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Topic'] = label_encoder.fit_transform(data['Topic'])
# C:\Users\damin\AppData\Local\Temp\ipykernel_23304\2554779994.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Semester'] = label_encoder.fit_transform(data['Semester'])
# C:\Users\damin\AppData\Local\Temp\ipykernel_23304\2554779994.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Relation'] = label_encoder.fit_transform(data['Relation'])
# C:\Users\damin\AppData\Local\Temp\ipykernel_23304\2554779994.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['ParentAnsweringSurvey'] = label_encoder.fit_transform(data['ParentAnsweringSurvey'])
# C:\Users\damin\AppData\Local\Temp\ipykernel_23304\2554779994.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['ParentschoolSatisfaction'] = label_encoder.fit_transform(data['ParentschoolSatisfaction'])
# C:\Users\damin\AppData\Local\Temp\ipykernel_23304\2554779994.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['StudentAbsenceDays'] = label_encoder.fit_transform(data['StudentAbsenceDays'])
# C:\Users\damin\AppData\Local\Temp\ipykernel_23304\2554779994.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Class'] = label_encoder.fit_transform(data['Class'])

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 478 entries, 0 to 479
# Data columns (total 17 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   gender                    478 non-null    int32
#  1   NationalITy               478 non-null    int32
#  2   PlaceofBirth              478 non-null    int32
#  3   StageID                   478 non-null    int32
#  4   GradeID                   478 non-null    int32
#  5   SectionID                 478 non-null    int32
#  6   Topic                     478 non-null    int32
#  7   Semester                  478 non-null    int32
#  8   Relation                  478 non-null    int32
#  9   raisedhands               478 non-null    int64
#  10  VisITedResources          478 non-null    int64
#  11  AnnouncementsView         478 non-null    int64
#  12  Discussion                478 non-null    int64
#  13  ParentAnsweringSurvey     478 non-null    int32
#  14  ParentschoolSatisfaction  478 non-null    int32
#  15  StudentAbsenceDays        478 non-null    int32
#  16  Class                     478 non-null    int32
# dtypes: int32(13), int64(4)
# memory usage: 42.9 KB

# %%
# List of numerical features to check for outliers
numerical_features = ['raisedhands', 'VisITedResources', 'AnnouncementsView', 'Discussion']

# Plot boxplots for each numerical feature
plt.figure(figsize=(10, 6))
for i, feature in enumerate(numerical_features, 1):
    plt.subplot(2, 2, i)
    sns.boxplot(data[feature])
    plt.title(f'Boxplot for {feature}')
plt.tight_layout()
plt.show()

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 478 entries, 0 to 479
# Data columns (total 17 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   gender                    478 non-null    int32
#  1   NationalITy               478 non-null    int32
#  2   PlaceofBirth              478 non-null    int32
#  3   StageID                   478 non-null    int32
#  4   GradeID                   478 non-null    int32
#  5   SectionID                 478 non-null    int32
#  6   Topic                     478 non-null    int32
#  7   Semester                  478 non-null    int32
#  8   Relation                  478 non-null    int32
#  9   raisedhands               478 non-null    int64
#  10  VisITedResources          478 non-null    int64
#  11  AnnouncementsView         478 non-null    int64
#  12  Discussion                478 non-null    int64
#  13  ParentAnsweringSurvey     478 non-null    int32
#  14  ParentschoolSatisfaction  478 non-null    int32
#  15  StudentAbsenceDays        478 non-null    int32
#  16  Class                     478 non-null    int32
# dtypes: int32(13), int64(4)
# memory usage: 42.9 KB

# %%
#min-max scalling
#scaling down numerical values
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()

numerical_columns = ['raisedhands', 'VisITedResources', 'AnnouncementsView', 'Discussion']

# Apply the scaler to the numerical columns
data[numerical_columns] = scaler.fit_transform(data[numerical_columns])
# Out:
# C:\Users\damin\AppData\Local\Temp\ipykernel_23304\608193232.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[numerical_columns] = scaler.fit_transform(data[numerical_columns])

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 478 entries, 0 to 479
# Data columns (total 17 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   gender                    478 non-null    int32
#  1   NationalITy               478 non-null    int32
#  2   PlaceofBirth              478 non-null    int32
#  3   StageID                   478 non-null    int32
#  4   GradeID                   478 non-null    int32
#  5   SectionID                 478 non-null    int32
#  6   Topic                     478 non-null    int32
#  7   Semester                  478 non-null    int32
#  8   Relation                  478 non-null    int32
#  9   raisedhands               478 non-null    float64
#  10  VisITedResources          478 non-null    float64
#  11  AnnouncementsView         478 non-null    float64
#  12  Discussion                478 non-null    float64
#  13  ParentAnsweringSurvey     478 non-null    int32
#  14  ParentschoolSatisfaction  478 non-null    int32
#  15  StudentAbsenceDays        478 non-null    int32
#  16  Class                     478 non-null    int32
# dtypes: float64(4), int32(13)
# memory usage: 42.9 KB

# %%
data
# Out:
#      gender  NationalITy  PlaceofBirth  StageID  GradeID  SectionID  Topic  \
# 0         1            4             4        2        1          0      7
# 1         1            4             4        2        1          0      7
# 2         1            4             4        2        1          0      7
# 3         1            4             4        2        1          0      7
# 4         1            4             4        2        1          0      7
# ..      ...          ...           ...      ...      ...        ...    ...
# 475       0            3             3        1        5          0      2
# 476       0            3             3        1        5          0      5
# 477       0            3             3        1        5          0      5
# 478       0            3             3        1        5          0      6
# 479       0            3             3        1        5          0      6
#
#      Semester  Relation  raisedhands  VisITedResources  AnnouncementsView  \
# 0           0         0         0.15          0.161616           0.020408
# 1           0         0         0.20          0.202020           0.030612
# 2           0         0         0.10          0.070707           0.000000
# 3           0         0         0.30          0.252525           0.051020
# 4           0         0         0.40          0.505051           0.122449
# ..        ...       ...          ...               ...                ...
# 475         1         0         0.05          0.040404           0.051020
# 476         0         0         0.50          0.777778           0.142857
# 477         1         0         0.55          0.747475           0.255102
# 478         0         0         0.30          0.171717           0.142857
# 479         1         0         0.35          0.141414           0.234694
#
#      Discussion  ParentAnsweringSurvey  ParentschoolSatisfaction  \
# 0      0.193878                      1                         1
# 1      0.244898                      1                         1
# 2      0.295918                      0                         0
# 3      0.346939                      0                         0
# 4      0.500000                      0                         0
# ..          ...                    ...                       ...
# 475    0.071429                      0                         0
# 476    0.275510                      0                         0
# 477    0.285714                      0                         0
# 478    0.571429                      0                         0
# 479    0.622449                      0                         0
#
#      StudentAbsenceDays  Class
# 0                     1      2
# 1                     1      2
# 2                     0      1
# 3                     0      1
# 4                     0      2
# ..                  ...    ...
# 475                   0      1
# 476                   1      2
# 477                   1      2
# 478                   0      1
# 479                   0      1
#
# [478 rows x 17 columns]

# %%
#Split the dataset into dependent and independent.
X = data.iloc[:,0:16]
Y = data.iloc[:,16:17]

# %%
X
# Out:
#      gender  NationalITy  PlaceofBirth  StageID  GradeID  SectionID  Topic  \
# 0         1            4             4        2        1          0      7
# 1         1            4             4        2        1          0      7
# 2         1            4             4        2        1          0      7
# 3         1            4             4        2        1          0      7
# 4         1            4             4        2        1          0      7
# ..      ...          ...           ...      ...      ...        ...    ...
# 475       0            3             3        1        5          0      2
# 476       0            3             3        1        5          0      5
# 477       0            3             3        1        5          0      5
# 478       0            3             3        1        5          0      6
# 479       0            3             3        1        5          0      6
#
#      Semester  Relation  raisedhands  VisITedResources  AnnouncementsView  \
# 0           0         0         0.15          0.161616           0.020408
# 1           0         0         0.20          0.202020           0.030612
# 2           0         0         0.10          0.070707           0.000000
# 3           0         0         0.30          0.252525           0.051020
# 4           0         0         0.40          0.505051           0.122449
# ..        ...       ...          ...               ...                ...
# 475         1         0         0.05          0.040404           0.051020
# 476         0         0         0.50          0.777778           0.142857
# 477         1         0         0.55          0.747475           0.255102
# 478         0         0         0.30          0.171717           0.142857
# 479         1         0         0.35          0.141414           0.234694
#
#      Discussion  ParentAnsweringSurvey  ParentschoolSatisfaction  \
# 0      0.193878                      1                         1
# 1      0.244898                      1                         1
# 2      0.295918                      0                         0
# 3      0.346939                      0                         0
# 4      0.500000                      0                         0
# ..          ...                    ...                       ...
# 475    0.071429                      0                         0
# 476    0.275510                      0                         0
# 477    0.285714                      0                         0
# 478    0.571429                      0                         0
# 479    0.622449                      0                         0
#
#      StudentAbsenceDays
# 0                     1
# 1                     1
# 2                     0
# 3                     0
# 4                     0
# ..                  ...
# 475                   0
# 476                   1
# 477                   1
# 478                   0
# 479                   0
#
# [478 rows x 16 columns]

# %%
Y
# Out:
#      Class
# 0        2
# 1        2
# 2        1
# 3        1
# 4        2
# ..     ...
# 475      1
# 476      2
# 477      2
# 478      1
# 479      1
#
# [478 rows x 1 columns]

# %%
#Split the dataset into training and validation sets.
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(X,Y, test_size=0.2, random_state=42)

# %%
X_train
# Out:
#      gender  NationalITy  PlaceofBirth  StageID  GradeID  SectionID  Topic  \
# 208       1           10            10        1        5          2     11
# 204       1            3             3        1        5          1      0
# 320       0            3             3        2        0          0      4
# 311       1            3             3        2        1          1     10
# 22        1            4             4        1        4          0      7
# ..      ...          ...           ...      ...      ...        ...    ...
# 106       0            4             4        2        0          1      7
# 270       0            3             3        1        3          0      3
# 350       1            0             0        2        0          1      4
# 437       1            3             3        1        5          0      5
# 102       0            4             4        2        0          1      7
#
#      Semester  Relation  raisedhands  VisITedResources  AnnouncementsView  \
# 208         1         1         0.27          0.414141           0.500000
# 204         1         0         0.29          0.101010           0.122449
# 320         0         1         0.60          0.878788           0.234694
# 311         1         0         0.42          0.343434           0.295918
# 22          0         0         0.15          0.212121           0.020408
# ..        ...       ...          ...               ...                ...
# 106         0         0         0.12          0.262626           0.071429
# 270         0         1         0.90          0.848485           0.530612
# 350         0         1         0.05          0.131313           0.061224
# 437         1         1         0.70          0.838384           0.714286
# 102         0         0         0.02          0.060606           0.020408
#
#      Discussion  ParentAnsweringSurvey  ParentschoolSatisfaction  \
# 208    0.132653                      0                         0
# 204    0.234694                      0                         0
# 320    0.102041                      1                         1
# 311    0.387755                      0                         1
# 22     0.908163                      0                         0
# ..          ...                    ...                       ...
# 106    0.397959                      1                         1
# 270    0.295918                      0                         1
# 350    0.051020                      0                         1
# 437    0.224490                      1                         1
# 102    0.071429                      0                         0
#
#      StudentAbsenceDays
# 208                   1
# 204                   0
# 320                   0
# 311                   0
# 22                    1
# ..                  ...
# 106                   1
# 270                   1
# 350                   0
# 437                   1
# 102                   0
#
# [382 rows x 16 columns]

# %%
X_train.shape
# Out:
# (382, 16)

# %%
#Model Design
import tensorflow as tf
from tensorflow.keras import layers, models

model = models.Sequential([
    layers.Dense(64, activation='relu', input_shape=(X_train.shape[1],)),
    layers.Dense(32, activation='relu'),
    layers.Dense(3, activation='softmax')  # For 3 classes
])
# Out:
# C:\Users\damin\anaconda3\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 64)             │         1,088 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 32)             │         2,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 3)              │            99 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 3,267 (12.76 KB)
#  Trainable params: 3,267 (12.76 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
#compile model
model.compile(
    loss = 'sparse_categorical_crossentropy',
    optimizer = 'adam',
    metrics = ['accuracy'])

# %%
#early stopping to prevent overfitting
#stop if val loss dosent improve in 5 consective epochs
early_stopping = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=5)

#Train your model on the training data
history = model.fit(
    X_train,
    Y_train, 
    epochs=50, #increesed to 50
    batch_size = 32, #incresed form 16 to 32
    validation_data=(X_test, Y_test), 
    callbacks=[early_stopping]
)
# Out:
# Epoch 1/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - accuracy: 0.2346 - loss: 1.7149 - val_accuracy: 0.3333 - val_loss: 1.1622
# Epoch 2/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.3297 - loss: 1.1487 - val_accuracy: 0.4688 - val_loss: 0.9988
# Epoch 3/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.4209 - loss: 1.0261 - val_accuracy: 0.5104 - val_loss: 0.9319
# Epoch 4/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5292 - loss: 0.9379 - val_accuracy: 0.6042 - val_loss: 0.8907
# Epoch 5/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5209 - loss: 0.9293 - val_accuracy: 0.6146 - val_loss: 0.8606
# Epoch 6/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5805 - loss: 0.8541 - val_accuracy: 0.6562 - val_loss: 0.8153
# Epoch 7/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5465 - loss: 0.8276 - val_accuracy: 0.6458 - val_loss: 0.7837
# Epoch 8/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6266 - loss: 0.7736 - val_accuracy: 0.6875 - val_loss: 0.7494
# Epoch 9/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6395 - loss: 0.7680 - val_accuracy: 0.6562 - val_loss: 0.7308
# Epoch 10/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6850 - loss: 0.7156 - val_accuracy: 0.7188 - val_loss: 0.6975
# Epoch 11/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6913 - loss: 0.6842 - val_accuracy: 0.7292 - val_loss: 0.6745
# Epoch 12/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7134 - loss: 0.6870 - val_accuracy: 0.7188 - val_loss: 0.6543
# Epoch 13/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7025 - loss: 0.6629 - val_accuracy: 0.7396 - val_loss: 0.6382
# Epoch 14/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7045 - loss: 0.6441 - val_accuracy: 0.7396 - val_loss: 0.6145
# Epoch 15/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7132 - loss: 0.6213 - val_accuracy: 0.7500 - val_loss: 0.6139
# Epoch 16/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7370 - loss: 0.6042 - val_accuracy: 0.7396 - val_loss: 0.5951
# Epoch 17/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7461 - loss: 0.5785 - val_accuracy: 0.7604 - val_loss: 0.5921
# Epoch 18/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7764 - loss: 0.5455 - val_accuracy: 0.7708 - val_loss: 0.5734
# Epoch 19/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7562 - loss: 0.5776 - val_accuracy: 0.7708 - val_loss: 0.5696
# Epoch 20/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7510 - loss: 0.5706 - val_accuracy: 0.7604 - val_loss: 0.5720
# Epoch 21/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8032 - loss: 0.5387 - val_accuracy: 0.8021 - val_loss: 0.5552
# Epoch 22/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7605 - loss: 0.5656 - val_accuracy: 0.7708 - val_loss: 0.5426
# Epoch 23/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7974 - loss: 0.5278 - val_accuracy: 0.7083 - val_loss: 0.5716
# Epoch 24/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8030 - loss: 0.5085 - val_accuracy: 0.7708 - val_loss: 0.5272
# Epoch 25/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7753 - loss: 0.5228 - val_accuracy: 0.7292 - val_loss: 0.5478
# Epoch 26/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7380 - loss: 0.5385 - val_accuracy: 0.8021 - val_loss: 0.5273
# Epoch 27/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8167 - loss: 0.4981 - val_accuracy: 0.8021 - val_loss: 0.5225
# Epoch 28/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7783 - loss: 0.5114 - val_accuracy: 0.7292 - val_loss: 0.5368
# Epoch 29/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7829 - loss: 0.4937 - val_accuracy: 0.8125 - val_loss: 0.5252
# Epoch 30/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7769 - loss: 0.4986 - val_accuracy: 0.7604 - val_loss: 0.5308
# Epoch 31/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7826 - loss: 0.4861 - val_accuracy: 0.7292 - val_loss: 0.5265
# Epoch 32/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7768 - loss: 0.5228 - val_accuracy: 0.8125 - val_loss: 0.5083
# Epoch 33/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7788 - loss: 0.5314 - val_accuracy: 0.7604 - val_loss: 0.5284
# Epoch 34/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7780 - loss: 0.4872 - val_accuracy: 0.8021 - val_loss: 0.5081
# Epoch 35/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7654 - loss: 0.5133 - val_accuracy: 0.7500 - val_loss: 0.5390
# Epoch 36/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8195 - loss: 0.4740 - val_accuracy: 0.8125 - val_loss: 0.5033
# Epoch 37/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7864 - loss: 0.4883 - val_accuracy: 0.7812 - val_loss: 0.5134
# Epoch 38/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7942 - loss: 0.4946 - val_accuracy: 0.8125 - val_loss: 0.4984
# Epoch 39/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7496 - loss: 0.5148 - val_accuracy: 0.8021 - val_loss: 0.4954
# Epoch 40/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7757 - loss: 0.5239 - val_accuracy: 0.7604 - val_loss: 0.5210
# Epoch 41/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7992 - loss: 0.4604 - val_accuracy: 0.8021 - val_loss: 0.5074
# Epoch 42/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8184 - loss: 0.4444 - val_accuracy: 0.7604 - val_loss: 0.5118
# Epoch 43/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8051 - loss: 0.4198 - val_accuracy: 0.7917 - val_loss: 0.4860
# Epoch 44/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8013 - loss: 0.4668 - val_accuracy: 0.7396 - val_loss: 0.5219
# Epoch 45/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8003 - loss: 0.4484 - val_accuracy: 0.8021 - val_loss: 0.5034
# Epoch 46/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7925 - loss: 0.4466 - val_accuracy: 0.8125 - val_loss: 0.4942
# Epoch 47/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8560 - loss: 0.4119 - val_accuracy: 0.7708 - val_loss: 0.5023
# Epoch 48/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8054 - loss: 0.4568 - val_accuracy: 0.8021 - val_loss: 0.4888

# %%
val_loss, val_accuracy = model.evaluate(X_test, Y_test)
print(f'Validation Loss: {val_loss}, Validation Accuracy: {val_accuracy}')

train_loss, train_accuracy = model.evaluate(X_train, Y_train)
print(f'Train Loss: {train_loss}, Train Accuracy: {train_accuracy}')
# Out:
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step - accuracy: 0.8112 - loss: 0.4614
# Validation Loss: 0.48878607153892517, Validation Accuracy: 0.8020833134651184
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7973 - loss: 0.4572
# Train Loss: 0.43649840354919434, Train Accuracy: 0.8089005351066589

# %%
#Plot variation in loss
plt.plot(history.history['loss'], label='train loss')
plt.plot(history.history['val_loss'], label='val loss')
plt.xlabel('Epoch')
plt.ylabel('loss')
plt.legend()
plt.savefig('lossGraph')
plt.show()

# %%
#Plot variation in accuracy
plt.plot(history.history['accuracy'], label='train accuracy')
plt.plot(history.history['val_accuracy'], label='val accuracy')
plt.xlabel('Epoch')
plt.ylabel('accuracy')
plt.legend()
plt.savefig('accGraph')
plt.show()

# %%
from sklearn.metrics import classification_report

# Predict probabilities
y_pred_prob = model.predict(X_train)

# Convert probabilities to class labels
y_pred = np.argmax(y_pred_prob, axis=1)

# Generate classification report
print(classification_report(Y_train, y_pred))
# Out:
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
#               precision    recall  f1-score   support
#
#            0       0.78      0.80      0.79       118
#            1       0.87      0.90      0.88        98
#            2       0.79      0.77      0.78       166
#
#     accuracy                           0.81       382
#    macro avg       0.81      0.82      0.82       382
# weighted avg       0.81      0.81      0.81       382
